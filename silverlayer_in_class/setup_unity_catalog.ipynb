-- %%
CREATE CATALOG IF NOT EXISTS supply_chain_in_class;

USE CATALOG supply_chain_in_class;

CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

CREATE VOLUME IF NOT EXISTS supply_chain_in_class.default.raw;

-- %%
%python

dbutils.fs.mkdirs("/Volumes/supply_chain_in_class/default/raw/data")
dbutils.fs.mkdirs("/Volumes/supply_chain_in_class/default/raw/logs")
dbutils.fs.mkdirs("/Volumes/supply_chain_in_class/default/raw/metadata")
